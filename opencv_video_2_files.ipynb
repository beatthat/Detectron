# %%
import cv2
import numpy as np
from os import path
import matplotlib.pyplot as plt
import numpy as np
import time
from utils.frame_generators import video2frames
# %matplotlib inline
# %autoreload 2
# Out:
# UsageError: Line magic function `%autoreload` not found.

# %%
PATH = path.join('.', 'data', 'video')
print('PATH=' + PATH)
# Out:
# PATH=./data/video

# %%
# !ls {PATH}
# Out:
# video_0.avi

# %%
video_path = path.join(PATH, 'video_0.avi')

frame_start = 3000
frame_count = 10
frame_stride = 60

frame_gen = video2frames(video_path, 
                         frame_start=frame_start,
                         frame_count=frame_count,
                         frame_stride=frame_stride,
                         logging=True)

fig=plt.figure(figsize=(4, 4*frame_count))

i = 1
for frame in frame_gen:
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    fig.add_subplot(frame_count, 1, i)
    plt.imshow(frame,cmap='gray')
    i += 1
    
plt.show()
# Out:
# read frame 3001 and yield as 0 in 4.05311584473e-06s
# read frame 3061 and yield as 1 in 5.96046447754e-06s
# read frame 3121 and yield as 2 in 3.81469726562e-06s
# read frame 3181 and yield as 3 in 5.00679016113e-06s
# read frame 3241 and yield as 4 in 5.00679016113e-06s
# read frame 3301 and yield as 5 in 5.96046447754e-06s
# read frame 3361 and yield as 6 in 4.05311584473e-06s
# read frame 3421 and yield as 7 in 5.00679016113e-06s
# read frame 3481 and yield as 8 in 3.81469726562e-06s
# read frame 3541 and yield as 9 in 5.00679016113e-06s
